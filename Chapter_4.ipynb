# %%
# 코드 4-1 파이토치를 사용한 MLP

# %%
# 코드 4-2 MLP 객체 생성

# %%
# 코드 4-3 랜덤한 입력으로 MLP 테스트하기

# %%
# 코드 4-4 MLP 분류기로 확률 출력하기 (apply_softmax = True)

# %%
# 코드 4-5 SurnameDataset.__getitem__()구현

# %%
# 코드 4-6 SurnameVectorizer 구현

# %%
# 코드 4-7 MLP 기반의 SurnameClassifier

# %%
# 코드 4-8 MLP 기반의 성씨 분류기를 위한 하이퍼파라미터와 프로그램 설정

# %%
# 코드 4-10 훈련 반복 코드의 일부

# %%
# 코드 4-11 기존 모델(분류기)을 사용한 추론: 주어진 이름의 국적 예측하기

# %%
# 코드 4-12 최상위 국적 k개 예측하기

# %%
# 코드 4-13 드롭아웃을 적용한 MLP

# %%
# 코드 4-14 인공 데이터와 Conv1d 클래스

# %%
# 코드 4-15 데이터에 반복 적용한 합성곱

# %%
# 코드 4-16

# %%
# 코드 4-17

# %%
# 코드 4-18

# %%
# 코드 4-19

# %%
# 코드 4-20

# %%
# 코드 4-21

# %%
# 코드 4-22

# %%
# 코드 2-1 텍스트 토큰화

import spacy

nlp = spacy.load('en')
#nlp = spacy.load('en_core_web_sm')
text = "Mary, don't slap the green witch"
print([str(token) for token in nlp(text.lower())])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-3d6a15978109> in <cell line: 5>()
#       3 import spacy
#       4
# ----> 5 nlp = spacy.load('en')
#       6 #nlp = spacy.load('en_core_web_sm')
#       7 text = "Mary, don't slap the green witch"
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#
# /usr/local/lib/python3.10/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     469         return load_model_from_path(name, **kwargs)  # type: ignore[arg-type]
#     470     if name in OLD_MODEL_SHORTCUTS:
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 88.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load('en_core_web_sm')  # Corrected line to load the downloaded model

# Your text
text = "Mary, don't slap the green witch"

# Process the text
doc = nlp(text.lower())

# Print each token
print([str(token) for token in doc])
# Out:
# ['mary', ',', 'do', "n't", 'slap', 'the', 'green', 'witch']

# %%
import spacy

# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load('en_core_web_sm')  # Corrected line to load the downloaded model

# Your text
text = "Mary, don't slap the green witch"

# Print each token
print([str(token) for token in nlp(text.lower())])
# Out:
# ['mary', ',', 'do', "n't", 'slap', 'the', 'green', 'witch']

# %%
from nltk.tokenize import TweetTokenizer
tweet=u"Snow White and the Seven Degrees \
#MakeMovieClod@midnight:-)"

tokenizer = TweetTokenizer()
print(tokenizer.tokenize(tweet.lower()))
# Out:
# ['snow', 'white', 'and', 'the', 'seven', 'degrees', '#makemovieclod', '@midnight', ':-)']

# %%
# 코드 2-2 텍스트에서 n-그램 만들기

def n_grams(text,n):
  '''
  takes tokens or text, returns a list of n-grams
  '''
  return [text[i:i+n] for i in range(len(text)-n+1)]

cleaned = ['mary',',',"n't","slap",'green','witch','.']
print(n_grams(cleaned,3))
# Out:
# [['mary', ',', "n't"], [',', "n't", 'slap'], ["n't", 'slap', 'green'], ['slap', 'green', 'witch'], ['green', 'witch', '.']]

# %%
# 코드 2-3 표제어 추출: 단어를 표제어로 바꿉니다.

import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(u"he was running late")
for token in doc:
  print('{} --> {}'.format(token,token.lemma_)) # lemma 표제어
# Out:
# he --> he
# was --> be
# running --> run
# late --> late

# %%
# 코드 2-4 품사 part of speech(POS) 태깅 tagging

import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Mary slapped the green witch.")
for token in doc:
  print('{} - {}'.format(token, token.pos_))
# Out:
# Mary - PROPN
# slapped - VERB
# the - DET
# green - ADJ
# witch - NOUN
# . - PUNCT

# %%
# 코드 2-5 명사구(NP) 부분 구문 분석 chunking, shallow parsing
# 정규식 regular expression

import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Mary slapped the green witch.")
for chunk in doc.noun_chunks:
  print('{} - {}'.format(chunk, chunk.label_))

  # 개체명 named entity
# Out:
# Mary - NP
# the green witch - NP
